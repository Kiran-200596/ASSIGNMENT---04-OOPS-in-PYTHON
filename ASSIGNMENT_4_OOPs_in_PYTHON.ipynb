# %% [markdown]
# ***Python OOPs Questions***

# %% [markdown]
# 1) What is Object-Oriented Programming (OOP)?
#
#    - OOP is a way of programming that uses objects and classes to structure code, making it modular, reusable, and easy to maintain.

# %% [markdown]
# 2) What is a class in OOP ?
#
#    - A class in Object-Oriented Programming (OOP) is a blueprint or template used to create objects.
#
#    - It defines what data (attributes) an object will have and what actions (methods) it can perform.

# %% [markdown]
# 3) What is an object in OOP ?
#
#    - An object in Object-Oriented Programming (OOP) is a real, usable instance of a class.
#
#    - It represents a specific entity that contains data (attributes) and can perform actions (methods) defined by its class.

# %% [markdown]
# 4) What is the difference between abstraction and encapsulation ?
#
#   - Abstraction : Abstraction means hiding the implementation details and showing only what is necessary to the user.
#     - Focuses on what an object does, not how it does it.
#
#   - Encapsulation : Encapsulation means wrapping data and methods together and restricting direct access to data.
#     - Focuses on protecting data from unauthorized access.

# %% [markdown]
# 5) What are dunder methods in Python ?
#
#    Dunder methods are special methods in Python that:
#      - Start and end with double underscores (__)
#      - Are also called magic methods or special methods
#      - Allow objects to interact with Python’s built-in behavior

# %% [markdown]
# 6) Explain the concept of inheritance in OOP.
#
#    - Inheritance : The process of child class receiving the properties of parent class.
#
#    - Inheritance is of 5 types :
#
#       - Single Inheritance
#       - Multi-level Inheritance
#       - Multiple Inheritance
#       - Hierarchial Inheritance
#       - Hybrid Inheritance

# %% [markdown]
# 7) What is polymorphism in OOP?
#
#    - Polymorphism in OOPs refers to an object taking several forms depending on the methods/data.
#
#    - Polymorphism in OOPs takes place in 2 ways :  Method Overloading and Method Over-riding.

# %% [markdown]
# 8) How is encapsulation achieved in Python ?
#
#    - Encapsulation means wrapping data and methods together and restricting direct access to data.
#
#   - Encapsulation is also called access modifier which happens in 3 ways :
#
#     - Public : accessible any where inside/outside of the class.
#     - Private : accessible only within its class and we make it private using __(double) before the variable name.
#     - Protected : Protected methods can be accessed within the class and its subclass using _(single) before the variable name.

# %% [markdown]
# 9) What is a constructor in Python ?
#
#    - A constructor is a special method that is automatically called when an object is created from a class.
#
#      - In Python, the constructor method is __init__().

# %% [markdown]
# 10. What are class and static methods in Python ?
#
#     -  class method is a method that:
#        - Works with the class itself, not a specific object
#        - Uses the @classmethod decorator
#        - Takes cls as the first parameter (represents the class)
#
#     - static method is a method that:
#        - Does not access class (cls) or instance (self) data
#        - Uses the @staticmethod decorator
#        - Behaves like a regular function, but belongs to the class namespace

# %% [markdown]
# 11. What is method overloading in Python ?
#
#     - Method Overloading : Method overloading means multiple methods with the same name but different parameters.

# %% [markdown]
# 12. What is method overriding in OOP ?
#
#     - Method Overriding : Method overriding occurs when a child class provides its own implementation of a method defined in the parent class.

# %% [markdown]
# 13. What is a property decorator in Python ?
#
#     - The @property decorator allows you to access a method like an attribute while still controlling how that attribute is read, modified, or deleted.
#      -  It helps implement encapsulation in a clean and Pythonic way.

# %% [markdown]
# 14. Why is polymorphism important in OOP?
#
#     - Polymorphism means one interface, many implementations.The same method call behaves differently depending on the object.
#
#       - Improves Code Flexibility
#       - Enables Runtime Decision Making
#       - Reduces Code Duplication
#       - Improves Maintainability
#       - Enables Real-World Modeling

# %% [markdown]
# 15. What is an abstract class in Python?
#
#     - An abstract class is a class that:
#       - Cannot be instantiated (you cannot create its object)
#       - Defines methods that must be implemented by its child classes
#       - It acts like a blueprint for other classes.

# %% [markdown]
# 16. What are the advantages of OOP?
#
#     - Modularity
#         - OOP divides a program into self-contained objects, making large systems easier to manage and understand.
#         - Each class handles a specific responsibility
#
#     - Reusability
#        - Once a class is written, it can be reused through inheritance.
#           - Reduces code duplication
#           - Saves development time
#
#     - Encapsulation (Data Security)
#       - Data is protected by restricting direct access and exposing only required methods.
#         - Prevents accidental misuse
#         - Improves data integrity
#     - Abstraction (Complexity Hiding)
#       - OOP hides complex implementation details and exposes only essential features.
#         - Cleaner interfaces
#         - Easier usage

# %% [markdown]
# 17. What is multiple inheritance in Python?
#
#     - Multiple inheritance is a feature in Python where a child class inherits from more than one parent class.

# %% [markdown]
# 18. What is the difference between a class variable and an instance variable?
#
#     - A class variable:
#       - Is shared by all objects of the class
#       - Is defined inside the class, outside methods
#       - Represents common data for all instances
#
#     - An instance variable:
#       - Is unique to each object
#       - Is defined using self
#       - Stores object-specific data

# %% [markdown]
# 19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python
#
#     - __str__() Method:
#
#       - Purpose:
#         - Provides a user-friendly, readable string representation of an object.
#         - Called by print(object)
#         - Meant for end users
#         - Should be easy to understand
#
#     - __repr__() Method :
#
#       - Purpose:
#         - Provides an official, unambiguous string representation of an object.
#         - Called by repr(object)
#         - Used in debugging and development
#         - Ideally should be able to recreate the object

# %% [markdown]
# 20. What is the significance of the ‘super()’ function in Python ?
#
#      - super() is a built-in function used to call methods of a parent (super) class from a child class.
#     - It is mainly used in inheritance to reuse parent class functionality.

# %% [markdown]
# 21. What is the significance of the __del__ method in Python ?
#
#     - __del__() is a destructor method in Python that is called when an object is about to be destroyed (i.e., when it is garbage-collected).
#      - It is used to perform cleanup actions before an object is removed from memory.

# %% [markdown]
# 22. What is the difference between @staticmethod and @classmethod in Python?
#
#     - A class method:
#        - Works with the class itself, not a specific object
#        - Uses the @classmethod decorator
#        - Takes cls as the first parameter (represents the class)
#
#     - A static method:
#       - Does not access class (cls) or instance (self) data
#       - Uses the @staticmethod decorator
#       - Acts like a regular function, but belongs to the class namespace

# %% [markdown]
# 23. How does polymorphism work in Python with inheritance ?
#
#     - In Python, polymorphism with inheritance allows:
#        - A parent class reference to point to child class objects.
#        - The same method name to behave differently depending on the object’s class.
#
#     - Polymorphism works through:
#       - Method overriding
#       - Dynamic typing
#       - Method Resolution Order (MRO)

# %% [markdown]
# 24. What is method chaining in Python OOP ?
#
#     - Method chaining is an OOP technique where multiple methods are called on the same object in a single statement.
#        - Each method returns the object itself (self), allowing the next method call.

# %% [markdown]
# 25. What is the purpose of the __call__ method in Python?
#
#     - __call__() is a dunder (magic) method that allows an object to be called like a function.
#       -  When you use parentheses on an object, Python internally calls its __call__() method.

# %% [markdown]
# ***OOPS PRACTICAL QUESTIONS***

# %%
#1). Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

class Animal():
  def speak(self):
    print("This is an Animal")

class Dog(Animal):
  def speak(self):
    print("Bark!")

dog = Dog()
dog.speak()
# Out:
# Bark!

# %%
# 2). Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both

import abc  # to achieve and initialise abstract method
class Shape():
  @abc.abstractmethod
  def calculted_Area(self):
    pass

class Circle(Shape):
  def calculted_Area(self):
    print("This is a circle and the area of the circle is (22/7)*(radius squared)")

class Rectangle(Shape):
  def calculted_Area(self):
    print("This is a rectangle and the area of the rectangle is  (length * breadth)")

circle = Circle()
circle.calculted_Area()


rectangle = Rectangle()
rectangle.calculted_Area()
# Out:
# This is a circle and the area of the circle is (22/7)*(radius squared)
# This is a rectangle and the area of the rectangle is  (length * breadth)

# %%
# 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car  and further derive a class ElectricCar that adds a battery attribute.


class Vehicle:
  def vehicle_info(self):
    print("This is vehicle information")

class Car(Vehicle):
  def car_info(self):
    print("This is the car information")

class ElectricCar(Car) :
  def electric_car_info(self, Battery):
    print("This is an electric car and runs on battery")

EC = ElectricCar()
EC.electric_car_info("Battery")
# Out:
# This is an electric car and runs on battery

# %%
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.

class Bird :
  def fly(self):
    print("The birds will fly")

class Sparrow(Bird):
  def fly(self):
    print("The Sparrow flies high in the sky")

class Penguin(Bird):
  def fly(self):
    print("The Penguin cannot fly in the sky")

birds = [Sparrow() , Penguin()]

for bird in birds:
  bird.fly()
# Out:
# The Sparrow flies high in the sky
# The Penguin cannot fly in the sky

# %%
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.

class BankAccount:
  def __init__(self,balance):
    self.__balance = balance

  def deposit(self,amount):
    self.__balance = self.__balance + amount

  def withdraw(self,amount):
    if self.__balance >= amount :
      self.__balance = self.__balance - amount

      return True
    else :
      return False

  def get_balance(self):
    return self.__balance

account1 = BankAccount(2000)
account1.deposit(1000)
account1.get_balance()
# Out:
# 3000

# %%
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

class Instrument:
    def play(self):
        print("Instrument is being played.")
class Guitar(Instrument):
    def play(self):
        print("Guitar is playing a melodious tune.")

class Piano(Instrument):
    def play(self):
        print("Piano is playing classical music.")
instruments = [Guitar(), Piano()]

for instrument in instruments:
    instrument.play()
# Out:
# Guitar is playing a melodious tune.
# Piano is playing classical music.

# %%
# 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

class MathOperations:

    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b


print("Addition:", MathOperations.add_numbers(10, 5))
print("Subtraction:", MathOperations.subtract_numbers(10, 5))
# Out:
# Addition: 15
# Subtraction: 5

# %%
# 8. Implement a class Person with a class method to count the total number of persons created.

class Person :
  total_persons = 0
  def __init__(self , name):
    self.name = name
    Person.total_persons = Person.total_persons + 1

  @classmethod
  def get_total_persons(cls):
    return cls.total_persons


p1 = Person("Alice")
p2 = Person("Bob")
p3 = Person("Charlie")

print("Total persons created:", Person.get_total_persons())
# Out:
# Total persons created: 3

# %%
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

f1 = Fraction(3, 4)
f2 = Fraction(5, 8)

print(f1)
print(f2)
# Out:
# 3/4
# 5/8

# %%
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"Vector({self.x}, {self.y})"
v1 = Vector(2, 3)
v2 = Vector(4, 5)

v3 = v1 + v2   # operator overloading

print(v3)
# Out:
# Vector(6, 8)

# %%
# 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

p1 = Person("Alice", 25)
p2 = Person("Kiran", 30)

p1.greet()
p2.greet()
# Out:
# Hello, my name is Alice and I am 25 years old.
# Hello, my name is Kiran and I am 30 years old.

# %%
# 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.

class Student :
  def __init__ (self , name ,grades):
    self.name = name
    self.grades = grades
  def average_grade(self):
    return sum(self.grades) / len(self.grades)

s1 = Student("Kiran", [95, 90, 98])
print(f"{s1.name}'s average grade:", s1.average_grade())
# Out:
# Kiran's average grade: 94.33333333333333

# %%
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

class Rectangle:
  def set_dimensions(self, length, width):
        self.length = length
        self.width = width

  def area(self):
        return self.length * self.width

r1 = Rectangle()
r1.set_dimensions(10, 5)

print("Area of rectangle:", r1.area() , "units")
# Out:
# Area of rectangle: 50 units

# %%
# 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.

class Employee:
    def calculate_salary(self, hours_worked, hourly_rate):
        return hours_worked * hourly_rate

class Manager(Employee):
    def calculate_salary(self, hours_worked, hourly_rate, bonus):
        base_salary = super().calculate_salary(hours_worked, hourly_rate)
        return base_salary + bonus
emp = Employee()
mgr = Manager()

print("Employee Salary:", emp.calculate_salary(40, 500))
print("Manager Salary:", mgr.calculate_salary(40, 500, 10000))
# Out:
# Employee Salary: 20000
# Manager Salary: 30000

# %%
# 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.

class Product :
  def __init__(self , name , price , quantity):
    self.name = name
    self.price = price
    self.quantity = quantity

  def total_price(self):
    return self.price * self.quantity
product = Product("Laptop", 50000, 2)
print(f"{product.name} Total Price:", product.total_price())
# Out:
# Laptop Total Price: 100000

# %%
 # 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.

from abc import ABC, abstractmethod

class Animal(ABC):

    @abstractmethod
    def sound(self):
        pass
class Cow(Animal):
    def sound(self):
        print("Cow says Moo")

class Sheep(Animal):
    def sound(self):
        print("Sheep says Baa")
animals = [Cow(), Sheep()]

for animal in animals:
    animal.sound()
# Out:
# Cow says Moo
# Sheep says Baa

# %%
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.

class Book:
  def __init__(self , title , author , year_published):
    self.title = title
    self.author = author
    self.year_published = year_published

  def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year Published: {self.year_published}"

b1 = Book("1984", "George Orwell", 1949)

print(b1.get_book_info())
# Out:
# Title: 1984, Author: George Orwell, Year Published: 1949

# %%
# 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

h1 = House("Bangalore", 5000000)
m1 = Mansion("Mysore Road", 25000000, 12)

print(h1.address, h1.price)
print(m1.address, m1.price, m1.number_of_rooms)
# Out:
# Bangalore 5000000
# Mysore Road 25000000 12
